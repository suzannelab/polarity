# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import ipyvolume as ipv
# %matplotlib inline

# %%
cs = np.linspace(1e-12, 3, 200)

fig, ax = plt.subplots()

entropy_term = cs * np.log(cs)

ax.plot(cs, entropy_term)
